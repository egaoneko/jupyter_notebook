# %% [markdown]
# # ML lab 02 - TensorFlow로 간단한 linear regression을 구현 (new)

# %% [markdown]
# ## Building graph using TF operations

# %% [markdown]
# ### Setup

# %%
import tensorflow as tf

# %%
# Try to find values for W and b to compute y_data = W * x_data + b
# We know that W should be 1 and b should be 0
# But let's use TensorFlow to figure it out
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %% [markdown]
# ### Placeholder

# %%
# Now we can use X and Y in place of x_data and y_data
# # placeholders for a tensor that will be always fed using feed_dict
# See http://stackoverflow.com/questions/36693740/
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

# %%
# Our hypothesis XW+b
hypothesis = X * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %% [markdown]
# ## Run/update graph and get results

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Fit the line
for step in range(2001):
    cost_val, W_val, b_val, _ = \
        sess.run([cost, W, b, train],
                 feed_dict={X: [1, 2, 3], Y: [1, 2, 3]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 0.0774286 [ 0.66537839] [ 0.6605776]
# 20 0.0600726 [ 0.71275073] [ 0.64345413]
# 40 0.054466 [ 0.72926366] [ 0.61453974]
# 60 0.049466 [ 0.74227422] [ 0.58578491]
# 80 0.0449259 [ 0.75441372] [ 0.55826718]
# 100 0.0408024 [ 0.76595789] [ 0.53203183]
# 120 0.0370573 [ 0.77695739] [ 0.50702834]
# 140 0.0336561 [ 0.78743958] [ 0.48319986]
# 160 0.030567 [ 0.7974292] [ 0.46049115]
# 180 0.0277614 [ 0.8069492] [ 0.43884978]
# 200 0.0252133 [ 0.81602192] [ 0.41822547]
# 220 0.0228992 [ 0.82466817] [ 0.39857039]
# 240 0.0207974 [ 0.83290815] [ 0.37983903]
# 260 0.0188885 [ 0.84076089] [ 0.36198801]
# 280 0.0171549 [ 0.84824455] [ 0.34497589]
# 300 0.0155803 [ 0.85537642] [ 0.32876328]
# 320 0.0141503 [ 0.86217326] [ 0.31331259]
# 340 0.0128515 [ 0.86865062] [ 0.29858807]
# 360 0.011672 [ 0.87482357] [ 0.28455546]
# 380 0.0106007 [ 0.88070637] [ 0.27118245]
# 400 0.00962769 [ 0.88631272] [ 0.25843784]
# 420 0.00874402 [ 0.89165562] [ 0.24629222]
# 440 0.00794147 [ 0.89674741] [ 0.2347174]
# 460 0.00721258 [ 0.90159988] [ 0.22368656]
# 480 0.00655055 [ 0.90622431] [ 0.21317409]
# 500 0.00594934 [ 0.91063142] [ 0.2031557]
# 520 0.00540327 [ 0.91483146] [ 0.19360812]
# 540 0.00490734 [ 0.91883397] [ 0.18450928]
# 560 0.00445693 [ 0.92264849] [ 0.17583805]
# 580 0.00404786 [ 0.92628372] [ 0.16757435]
# 600 0.00367633 [ 0.92974818] [ 0.15969899]
# 620 0.0033389 [ 0.93304974] [ 0.1521937]
# 640 0.00303244 [ 0.93619609] [ 0.14504115]
# 660 0.00275412 [ 0.93919456] [ 0.13822484]
# 680 0.00250134 [ 0.94205225] [ 0.1317288]
# 700 0.00227175 [ 0.94477564] [ 0.12553802]
# 720 0.00206324 [ 0.94737101] [ 0.11963817]
# 740 0.00187387 [ 0.9498443] [ 0.11401565]
# 760 0.00170188 [ 0.95220143] [ 0.10865732]
# 780 0.00154567 [ 0.95444781] [ 0.10355084]
# 800 0.0014038 [ 0.95658857] [ 0.09868434]
# 820 0.00127496 [ 0.95862883] [ 0.09404656]
# 840 0.00115794 [ 0.96057314] [ 0.08962665]
# 860 0.00105165 [ 0.96242601] [ 0.08541452]
# 880 0.000955131 [ 0.96419191] [ 0.08140033]
# 900 0.000867464 [ 0.96587473] [ 0.07757479]
# 920 0.000787845 [ 0.96747851] [ 0.07392907]
# 940 0.000715534 [ 0.96900684] [ 0.07045466]
# 960 0.000649859 [ 0.97046345] [ 0.06714359]
# 980 0.000590209 [ 0.97185159] [ 0.06398806]
# 1000 0.000536038 [ 0.97317445] [ 0.06098083]
# 1020 0.000486842 [ 0.97443515] [ 0.05811496]
# 1040 0.000442155 [ 0.97563654] [ 0.05538376]
# 1060 0.000401571 [ 0.97678161] [ 0.05278093]
# 1080 0.000364713 [ 0.97787279] [ 0.05030043]
# 1100 0.000331238 [ 0.97891265] [ 0.04793651]
# 1120 0.000300837 [ 0.97990364] [ 0.04568374]
# 1140 0.000273227 [ 0.98084813] [ 0.04353674]
# 1160 0.000248148 [ 0.98174816] [ 0.04149067]
# 1180 0.000225371 [ 0.98260593] [ 0.03954077]
# 1200 0.000204685 [ 0.98342341] [ 0.03768249]
# 1220 0.000185899 [ 0.98420244] [ 0.03591154]
# 1240 0.000168835 [ 0.98494494] [ 0.03422381]
# 1260 0.000153339 [ 0.98565245] [ 0.0326154]
# 1280 0.000139267 [ 0.98632669] [ 0.0310826]
# 1300 0.000126485 [ 0.98696929] [ 0.02962185]
# 1320 0.000114874 [ 0.98758167] [ 0.02822972]
# 1340 0.000104331 [ 0.98816526] [ 0.02690306]
# 1360 9.47545e-05 [ 0.98872143] [ 0.02563875]
# 1380 8.60573e-05 [ 0.98925155] [ 0.02443382]
# 1400 7.81613e-05 [ 0.98975641] [ 0.02328563]
# 1420 7.09858e-05 [ 0.99023801] [ 0.02219138]
# 1440 6.4471e-05 [ 0.99069685] [ 0.02114842]
# 1460 5.85535e-05 [ 0.99113399] [ 0.02015451]
# 1480 5.31803e-05 [ 0.99155068] [ 0.01920731]
# 1500 4.82981e-05 [ 0.99194777] [ 0.01830462]
# 1520 4.38652e-05 [ 0.9923262] [ 0.01744436]
# 1540 3.98391e-05 [ 0.99268681] [ 0.01662453]
# 1560 3.61823e-05 [ 0.99303049] [ 0.01584326]
# 1580 3.28611e-05 [ 0.99335808] [ 0.01509871]
# 1600 2.98456e-05 [ 0.99367023] [ 0.01438911]
# 1620 2.71062e-05 [ 0.99396765] [ 0.01371288]
# 1640 2.46187e-05 [ 0.99425119] [ 0.01306843]
# 1660 2.23585e-05 [ 0.99452138] [ 0.01245425]
# 1680 2.03059e-05 [ 0.99477887] [ 0.01186893]
# 1700 1.84422e-05 [ 0.99502426] [ 0.01131111]
# 1720 1.67499e-05 [ 0.99525809] [ 0.01077951]
# 1740 1.52122e-05 [ 0.99548095] [ 0.01027291]
# 1760 1.38158e-05 [ 0.99569333] [ 0.00979011]
# 1780 1.25483e-05 [ 0.99589568] [ 0.00933001]
# 1800 1.13963e-05 [ 0.99608856] [ 0.00889153]
# 1820 1.03502e-05 [ 0.99627244] [ 0.00847366]
# 1840 9.40025e-06 [ 0.99644762] [ 0.00807543]
# 1860 8.53723e-06 [ 0.99661458] [ 0.00769591]
# 1880 7.75395e-06 [ 0.99677366] [ 0.00733422]
# 1900 7.04207e-06 [ 0.99692529] [ 0.00698952]
# 1920 6.39558e-06 [ 0.99706978] [ 0.00666105]
# 1940 5.80866e-06 [ 0.99720746] [ 0.00634803]
# 1960 5.27582e-06 [ 0.99733871] [ 0.00604971]
# 1980 4.79169e-06 [ 0.99746382] [ 0.0057654]
# 2000 4.35163e-06 [ 0.99758297] [ 0.00549445]

# %% [markdown]
# ## Testing our model

# %%
# Testing out model
print(sess.run(hypothesis, feed_dict={X: [5]}))
print(sess.run(hypothesis, feed_dict={X: [2.5]}))
print(sess.run(hypothesis, feed_dict={X: [1.5, 3.5]}))
# Out:
# [ 4.99340963]
# [ 2.49945188]
# [ 1.50186896  3.49703479]
