# %% [markdown]
# # 필드(Field)

# %% [markdown]
# ## 필드의 추상화

# %%
def solve1(a, b, c):
    return (c-b) / a

# %%
solve1(10, 5, 30)
# Out:
# 2.5

# %%
solve1(10+5j, 5, 20)
# Out:
# (1.2-0.6j)

# %% [markdown]
# ## 복소수 필드 $\mathbb C$ 다루기

# %%
from resources.plotting import plot

S = {2 + 2j, 3 + 2j, 1.75 + 1j, 2 + 1j, 2.25 + 1j, 2.5 + 1j, 2.75 + 1j, 3 + 1j, 3.25 + 1j}
plot(S, 4)

# %%
from resources.plotting import plot

S = {2 + 2j, 3 + 2j, 1.75 + 1j, 2 + 1j, 2.25 + 1j, 2.5 + 1j, 2.75 + 1j, 3 + 1j, 3.25 + 1j}
plot({-1 - 2j + z for z in S}, 4)

# %%
from resources.plotting import plot

S = {2 + 2j, 3 + 2j, 1.75 + 1j, 2 + 1j, 2.25 + 1j, 2.5 + 1j, 2.75 + 1j, 3 + 1j, 3.25 + 1j}
plot({1/2 * z for z in S}, 4)

# %%
from resources.plotting import plot

S = {2 + 2j, 3 + 2j, 1.75 + 1j, 2 + 1j, 2.25 + 1j, 2.5 + 1j, 2.75 + 1j, 3 + 1j, 3.25 + 1j}
plot({2 * z for z in S}, 4)

# %%
from resources.plotting import plot

S = {2 + 2j, 3 + 2j, 1.75 + 1j, 2 + 1j, 2.25 + 1j, 2.5 + 1j, 2.75 + 1j, 3 + 1j, 3.25 + 1j}
plot({-1 * z for z in S}, 4)

# %%
from resources.plotting import plot

S = {2 + 2j, 3 + 2j, 1.75 + 1j, 2 + 1j, 2.25 + 1j, 2.5 + 1j, 2.75 + 1j, 3 + 1j, 3.25 + 1j}
plot({-0.5j * z + 2 - 1j for z in S}, 4)

# %%
from resources.plotting import plot
from resources.image import file2image, color2gray

path = './img/img01.png'
data = color2gray(file2image(path))
data.reverse()
pts = { x + y * 1j
       for y, row in enumerate(data)
       for x, bright in enumerate(row)
       if bright < 120
      }
plot(pts, 200)

# %%
from resources.plotting import plot
from math import e, pi

N = 20
W = e ** (2 * pi * 1j / N)
S = { W ** i for i in range(N)}
plot(S, 2)

# %%
from resources.plotting import plot
from math import e, pi

W = e ** (pi/4 * 1j)
S = {2 + 2j, 3 + 2j, 1.75 + 1j, 2 + 1j, 2.25 + 1j, 2.5 + 1j, 2.75 + 1j, 3 + 1j, 3.25 + 1j}
plot({z * W for z in S}, 4)

# %%
from resources.plotting import plot
from resources.image import file2image, color2gray
from math import e, pi

W = e ** (pi/4 * 1j)
path = './img/img01.png'
data = color2gray(file2image(path))
data.reverse()
pts = { (x + y * 1j) * W
       for y, row in enumerate(data)
       for x, bright in enumerate(row)
       if bright < 120
      }
plot(pts, 200)

# %%
from resources.plotting import plot
from resources.image import file2image, color2gray
from math import e, pi

W = e ** (pi/4 * 1j)
T = - 100 - 100j
path = './img/img01.png'
data = color2gray(file2image(path))
data.reverse()
pts = { (x + y * 1j + T ) * W
       for y, row in enumerate(data)
       for x, bright in enumerate(row)
       if bright < 120
      }
plot(pts, 200)
